# %%
import pandas as pd

# %%
# Method 1: specify full path to file
stats = pd.read_csv('/Users/esara/go/src/github.com/esara/superdatascience/python/Section5_Demographic-Data.csv')

# %%
stats
# Out:
#              Country Name Country Code  Birth rate  Internet users  \
# 0                   Aruba          ABW      10.244            78.9
# 1             Afghanistan          AFG      35.253             5.9
# 2                  Angola          AGO      45.985            19.1
# 3                 Albania          ALB      12.877            57.2
# 4    United Arab Emirates          ARE      11.044            88.0
# ..                    ...          ...         ...             ...
# 190           Yemen, Rep.          YEM      32.947            20.0
# 191          South Africa          ZAF      20.850            46.5
# 192      Congo, Dem. Rep.          COD      42.394             2.2
# 193                Zambia          ZMB      40.471            15.4
# 194              Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ...

# %%
# Method 2: Change working directory
import os
#print (os.getcwd())
#os.chdir('/Users/esara/go/src/github.com/esara/superdatascience/python')
#print (os.getcwd())
stats2 = pd.read_csv('Section5_Demographic-Data.csv')

# %%
# Exploring dataset
len(stats)
stats.columns
len(stats.columns)
stats.head(6)
stats.tail(10)
stats.info # Similar to str function in R
stats.describe().transpose() # Like summary function in R (only for numerical colums)
# Out:
#                 count       mean        std  min      25%    50%      75%  \
# Birth rate      195.0  21.469928  10.605467  7.9  12.1205  19.68  29.7595
# Internet users  195.0  42.076471  29.030788  0.9  14.5200  41.00  66.2250
#
#                     max
# Birth rate      49.6610
# Internet users  96.5468

# %%
# Rename columns in datasets
stats2.columns
stats2.head()
stats2.columns = ['a', 'b', 'c', 'd','e']
stats2.head()
# Out:
#                       a    b       c     d                    e
# 0                 Aruba  ABW  10.244  78.9          High income
# 1           Afghanistan  AFG  35.253   5.9           Low income
# 2                Angola  AGO  45.985  19.1  Upper middle income
# 3               Albania  ALB  12.877  57.2  Upper middle income
# 4  United Arab Emirates  ARE  11.044  88.0          High income

# %%
# Subsetting dataframes in Pandas
stats[21:26] # slice by rows not columns by default
stats[:10] # same as head
stats[::-1] # reverse order
stats[::20] # every 20th row
# Out:
#               a    b       c        d                    e
# 0         Aruba  ABW  10.244  78.9000          High income
# 20      Belarus  BLR  12.500  54.1700  Upper middle income
# 40   Costa Rica  CRI  15.022  45.9600  Upper middle income
# 60        Gabon  GAB  30.555   9.2000  Upper middle income
# 80        India  IND  20.291  15.1000  Lower middle income
# 100       Libya  LBY  21.425  16.5000  Upper middle income
# 120  Mozambique  MOZ  39.705   5.4000           Low income
# 140      Poland  POL   9.600  62.8492          High income
# 160    Suriname  SUR  18.455  37.4000  Upper middle income
# 180     Uruguay  URY  14.374  57.6900          High income

# %%
# Column names
stats['Country Name']
stats[['Country Name', 'Birth rate']]
# Out:
#              Country Name  Birth rate
# 0                   Aruba      10.244
# 1             Afghanistan      35.253
# 2                  Angola      45.985
# 3                 Albania      12.877
# 4    United Arab Emirates      11.044
# ..                    ...         ...
# 190           Yemen, Rep.      32.947
# 191          South Africa      20.850
# 192      Congo, Dem. Rep.      42.394
# 193                Zambia      40.471
# 194              Zimbabwe      35.715
#
# [195 rows x 2 columns]

# %%
# Basic operations with dataframes
results = stats['Internet users'] * stats['Birth rate']
results = stats2['c'] * stats2['d']
results = stats2.c * stats2.d
print(results)
# Out:
# 0      808.2516
# 1      207.9927
# 2      878.3135
# 3      736.5644
# 4      971.8720
#          ...
# 190    658.9400
# 191    969.5250
# 192     93.2668
# 193    623.2534
# 194    660.7275
# Length: 195, dtype: float64

# %%
# Adding and Removing columns
stats['MyCalc'] = stats['Internet users'] * stats['Birth rate']
stats.drop('MyCalc', axis=1)
# Out:
#              Country Name Country Code  Birth rate  Internet users  \
# 0                   Aruba          ABW      10.244            78.9
# 1             Afghanistan          AFG      35.253             5.9
# 2                  Angola          AGO      45.985            19.1
# 3                 Albania          ALB      12.877            57.2
# 4    United Arab Emirates          ARE      11.044            88.0
# ..                    ...          ...         ...             ...
# 190           Yemen, Rep.          YEM      32.947            20.0
# 191          South Africa          ZAF      20.850            46.5
# 192      Congo, Dem. Rep.          COD      42.394             2.2
# 193                Zambia          ZMB      40.471            15.4
# 194              Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ...

# %%
# Filtering data frames (rows)
#Filter = stats['Internet users'] < 2
#stats[Filter]
stats[stats['Internet users'] < 2]
# Out:
#      Country Name Country Code  Birth rate  Internet users  \
# 11        Burundi          BDI      44.151             1.3
# 52        Eritrea          ERI      34.800             0.9
# 55       Ethiopia          ETH      32.925             1.9
# 64         Guinea          GIN      37.337             1.6
# 117       Myanmar          MMR      18.119             1.6
# 127         Niger          NER      49.661             1.7
# 154  Sierra Leone          SLE      36.729             1.7
# 156       Somalia          SOM      43.891             1.5
# 172   Timor-Leste          TLS      35.755             1.1
#
#             Income Group
# 11            Low income
# 52            Low income
# 55            Low income
# 64            Low income
# 117  Lower middle income
# 127           Low income
# 154           Low income
# 156           Low income
# 172  Lower middle income

# %%
#stats[stats['Internet users'] < 2 and stats['Birth rate'] > 40] # Does not work because python is not vectorized lang
#Filter1 = stats['Internet users'] < 2
#Filter2 = stats['Birth rate'] > 40
#stats[Filter1 & Filter2]
stats[(stats['Internet users'] < 2) & (stats['Birth rate'] > 40)]
# Out:
#     Country Name Country Code  Birth rate  Internet users Income Group
# 11       Burundi          BDI      44.151             1.3   Low income
# 127        Niger          NER      49.661             1.7   Low income
# 156      Somalia          SOM      43.891             1.5   Low income

# %%
stats[stats['Income Group'] == 'High income']
# Out:
#               Country Name Country Code  Birth rate  Internet users  \
# 0                    Aruba          ABW      10.244           78.90
# 4     United Arab Emirates          ARE      11.044           88.00
# 5                Argentina          ARG      17.716           59.90
# 7      Antigua and Barbuda          ATG      16.447           63.40
# 8                Australia          AUS      13.200           83.00
# ..                     ...          ...         ...             ...
# 174    Trinidad and Tobago          TTO      14.590           63.80
# 180                Uruguay          URY      14.374           57.69
# 181          United States          USA      12.500           84.20
# 184          Venezuela, RB          VEN      19.842           54.90
# 185  Virgin Islands (U.S.)          VIR      10.700           45.30
#
#     Income Group
# 0    High income
# 4    High income
# 5    High income
# 7    High income
# 8    High income
# ..           ...
# 174  High income
# ...

# %%
stats['Income Group'].unique()
# Out:
# array(['High income', 'Low income', 'Upper middle income',
#        'Lower middle income'], dtype=object)

# %%
stats[stats['Country Name'] == 'Malta']
# Out:
#     Country Name Country Code  Birth rate  Internet users Income Group
# 116        Malta          MLT         9.5         68.9138  High income

# %%
#.iat for integer location
#.at for labels
stats.iat[3,4]
stats.iat[0,1]
stats.at[2,'Birth rate']
# Out:
# 45.985

# %%
sub10 = stats[::10]
sub10.iat[10,0] # Lybia which is number 10
sub10.at[10,'Country Name'] # Azerbaijan which is labeled 10
# Out:
# 'Azerbaijan'

# %%
# Introduction to seaborn
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
vis1 = sns.distplot(stats['Internet users'])

# %%
vis1 = sns.distplot(stats['Internet users'], bins=30)

# %%
vis2 = sns.boxplot(data=stats, x='Income Group', y='Birth rate')

# %%
# Seaborn gallery
#vis3 = sns.lmplot(data=stats, x='Internet users', y='Birth rate') # by default with linear regression
#vis3 = sns.lmplot(data=stats, x='Internet users', y='Birth rate', fit_reg=False, hue='Income Group')
vis3 = sns.lmplot(data=stats, x='Internet users', y='Birth rate', fit_reg=False, hue='Income Group', size=10)
#vis3 = sns.lmplot(data=stats, x='Internet users', y='Birth rate', fit_reg=False, hue='Income Group', size=10, aspect=2)

# %%
# keyword arguments https://seaborn.pydata.org/generated/seaborn.scatterplot.html
# marker size https://matplotlib.org/stable/gallery/shapes_and_collections/scatter.html
vis3 = sns.lmplot(data=stats, x='Internet users', y='Birth rate', \
                  fit_reg=False, hue='Income Group', size=10, scatter_kws={"s":100})
